# %% [markdown]
# EJERCICIO 33

# %%
import numpy as np
from scipy.stats import chi2

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: σ^2 = 0.5 (La varianza poblacional es 0.5 mm^2)
# Ha: σ^2 < 0.5 (La varianza poblacional es menor a 0.5 mm^2)

# 2. Definir variables
sigma2_0 = 0.5  # Varianza poblacional hipotetizada
s2 = 0.3  # Varianza muestral
n = 12  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución chi-cuadrado

# Requerimiento 2: Calcule el estadístico χ^2.
estadistico_chi2 = ((n - 1) * s2) / sigma2_0

print(f"Estadístico χ² calculado: {estadistico_chi2:.2f}")

# Requerimiento 3: Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# Para una prueba de cola inferior con alpha = 0.05
valor_critico_chi2_inferior = chi2.ppf(alpha, grados_libertad)

print(f"Grados de libertad: {grados_libertad}")
print(f"Valor crítico χ² (alpha = {alpha}): {valor_critico_chi2_inferior:.2f}")
print(f"Región de rechazo: χ² < {valor_critico_chi2_inferior:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_chi2 < valor_critico_chi2_inferior:
    print(f"El estadístico χ² ({estadistico_chi2:.2f}) cae en la región de rechazo.")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia al 5% de significancia para concluir que la varianza poblacional del grosor de las piezas es menor a 0.5 mm².")
else:
    print(f"El estadístico χ² ({estadistico_chi2:.2f}) no cae en la región de rechazo.")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia al 5% de significancia para concluir que la varianza poblacional del grosor de las piezas es menor a 0.5 mm².")
# Out:
# Estadístico χ² calculado: 6.60
# Grados de libertad: 11
# Valor crítico χ² (alpha = 0.05): 4.57
# Región de rechazo: χ² < 4.57
#
# Conclusión:
# El estadístico χ² (6.60) no cae en la región de rechazo.
# No se rechaza la hipótesis nula (H0).
# No hay suficiente evidencia al 5% de significancia para concluir que la varianza poblacional del grosor de las piezas es menor a 0.5 mm².

# %% [markdown]
# EJERCICIO 32

# %%
import numpy as np
from scipy.stats import chi2

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: σ^2 = 1.2 (La varianza poblacional es 1.2 ml^2)
# Ha: σ^2 > 1.2 (La varianza poblacional es mayor a 1.2 ml^2)

# 2. Definir variables
sigma2_0 = 1.2  # Varianza poblacional hipotetizada
s2 = 2.0  # Varianza muestral
n = 20  # Tamaño de la muestra
alpha = 0.01  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución chi-cuadrado

# Requerimiento 2: Calcule el estadístico χ^2.
estadistico_chi2 = ((n - 1) * s2) / sigma2_0

print(f"Estadístico χ² calculado: {estadistico_chi2:.2f}")

# Requerimiento 3: Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# Para una prueba de cola superior con alpha = 0.01
valor_critico_chi2_superior = chi2.ppf(1 - alpha, grados_libertad)

print(f"Grados de libertad: {grados_libertad}")
print(f"Valor crítico χ² (alpha = {alpha}): {valor_critico_chi2_superior:.2f}")
print(f"Región de rechazo: χ² > {valor_critico_chi2_superior:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_chi2 > valor_critico_chi2_superior:
    print(f"El estadístico χ² ({estadistico_chi2:.2f}) cae en la región de rechazo.")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia al 1% de significancia para concluir que la varianza poblacional del llenado es mayor a 1.2 ml².")
else:
    print(f"El estadístico χ² ({estadistico_chi2:.2f}) no cae en la región de rechazo.")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia al 1% de significancia para concluir que la varianza poblacional del llenado es mayor a 1.2 ml².")
# Out:
# Estadístico χ² calculado: 31.67
# Grados de libertad: 19
# Valor crítico χ² (alpha = 0.01): 36.19
# Región de rechazo: χ² > 36.19
#
# Conclusión:
# El estadístico χ² (31.67) no cae en la región de rechazo.
# No se rechaza la hipótesis nula (H0).
# No hay suficiente evidencia al 1% de significancia para concluir que la varianza poblacional del llenado es mayor a 1.2 ml².

# %% [markdown]
# EJERCICIO 31

# %%
import numpy as np
from scipy.stats import chi2

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: σ^2 = 2.5 (La varianza poblacional es 2.5 minutos^2)
# Ha: σ^2 ≠ 2.5 (La varianza poblacional difiere de 2.5 minutos^2)

# 2. Definir variables
sigma2_0 = 2.5  # Varianza poblacional hipotetizada
s2 = 4  # Varianza muestral
n = 16  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución chi-cuadrado

# Requerimiento 2: Calcule el estadístico χ^2.
estadistico_chi2 = ((n - 1) * s2) / sigma2_0

print(f"Estadístico χ² calculado: {estadistico_chi2:.2f}")

# Requerimiento 3: Determine los grados de libertad y los valores críticos, además de la región crítica y la región de rechazo.
# Para una prueba de dos colas con alpha = 0.05
alpha_div_2 = alpha / 2
valor_critico_chi2_inferior = chi2.ppf(alpha_div_2, grados_libertad)
valor_critico_chi2_superior = chi2.ppf(1 - alpha_div_2, grados_libertad)

print(f"Grados de libertad: {grados_libertad}")
print(f"Valores críticos χ² (alpha = {alpha}): {valor_critico_chi2_inferior:.2f} y {valor_critico_chi2_superior:.2f}")
print(f"Región de rechazo: χ² < {valor_critico_chi2_inferior:.2f} o χ² > {valor_critico_chi2_superior:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_chi2 < valor_critico_chi2_inferior or estadistico_chi2 > valor_critico_chi2_superior:
    print(f"El estadístico χ² ({estadistico_chi2:.2f}) cae en la región de rechazo.")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que la varianza poblacional del tiempo de duración de las llamadas difiere de 2.5 minutos².")
else:
    print(f"El estadístico χ² ({estadistico_chi2:.2f}) no cae en la región de rechazo.")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que la varianza poblacional del tiempo de duración de las llamadas difiere de 2.5 minutos².")
# Out:
# Estadístico χ² calculado: 24.00
# Grados de libertad: 15
# Valores críticos χ² (alpha = 0.05): 6.26 y 27.49
# Región de rechazo: χ² < 6.26 o χ² > 27.49
#
# Conclusión:
# El estadístico χ² (24.00) no cae en la región de rechazo.
# No se rechaza la hipótesis nula (H0).
# No hay suficiente evidencia para concluir que la varianza poblacional del tiempo de duración de las llamadas difiere de 2.5 minutos².

# %% [markdown]
# EJERCICIO 30

# %%
import numpy as np
from scipy.stats import t

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 10000 (La duración promedio de los focos es de 10,000 horas)
# Ha: μ < 10000 (La duración promedio de los focos es menor a 10,000 horas)

# 2. Definir variables
mu_0 = 10000  # Media poblacional hipotetizada
media_muestral = 9800  # Media de la muestra
desviacion_estandar_muestral = 300  # Desviación estándar de la muestra
n = 20  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución t

# Requerimiento 2: Calcule el estadístico t.
error_estandar = desviacion_estandar_muestral / np.sqrt(n)
estadistico_t = (media_muestral - mu_0) / error_estandar

print(f"Estadístico t calculado: {estadistico_t:.2f}")

# Requerimiento 3: Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# Para una prueba de cola inferior con alpha = 0.05
valor_critico_t = t.ppf(alpha, grados_libertad)

print(f"Grados de libertad: {grados_libertad}")
print(f"Valor crítico t (alpha = {alpha}): {valor_critico_t:.2f}")
print(f"Región de rechazo: t < {valor_critico_t:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_t < valor_critico_t:
    print(f"El estadístico t ({estadistico_t:.2f}) es menor que el valor crítico t ({valor_critico_t:.2f}).")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que la duración promedio de los focos es menor a 10,000 horas.")
else:
    print(f"El estadístico t ({estadistico_t:.2f}) no es menor que el valor crítico t ({valor_critico_t:.2f}).")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que la duración promedio de los focos es menor a 10,000 horas.")
# Out:
# Estadístico t calculado: -2.98
# Grados de libertad: 19
# Valor crítico t (alpha = 0.05): -1.73
# Región de rechazo: t < -1.73
#
# Conclusión:
# El estadístico t (-2.98) es menor que el valor crítico t (-1.73).
# Se rechaza la hipótesis nula (H0).
# Hay suficiente evidencia para concluir que la duración promedio de los focos es menor a 10,000 horas.

# %% [markdown]
# EJERCICIO 29

# %%
import numpy as np
from scipy.stats import t

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 2 (El aumento promedio es de 2 mg/dL)
# Ha: μ < 2 (El aumento promedio es menor a 2 mg/dL)

# 2. Definir variables
mu_0 = 2  # Media poblacional hipotetizada
media_muestral = 1.5  # Media de la muestra
desviacion_estandar_muestral = 0.6  # Desviación estándar de la muestra
n = 8  # Tamaño de la muestra
alpha = 0.10  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución t

# Requerimiento 2: Calcule el estadístico t.
error_estandar = desviacion_estandar_muestral / np.sqrt(n)
estadistico_t = (media_muestral - mu_0) / error_estandar

print(f"Estadístico t calculado: {estadistico_t:.2f}")

# Requerimiento 3: Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# Para una prueba de cola inferior con alpha = 0.10
valor_critico_t = t.ppf(alpha, grados_libertad)

print(f"Grados de libertad: {grados_libertad}")
print(f"Valor crítico t (alpha = {alpha}): {valor_critico_t:.2f}")
print(f"Región de rechazo: t < {valor_critico_t:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_t < valor_critico_t:
    print(f"El estadístico t ({estadistico_t:.2f}) es menor que el valor crítico t ({valor_critico_t:.2f}).")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el aumento promedio de hierro en la sangre es menor a 2 mg/dL.")
else:
    print(f"El estadístico t ({estadistico_t:.2f}) no es menor que el valor crítico t ({valor_critico_t:.2f}).")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el aumento promedio de hierro en la sangre es menor a 2 mg/dL.")
# Out:
# Estadístico t calculado: -2.36
# Grados de libertad: 7
# Valor crítico t (alpha = 0.1): -1.41
# Región de rechazo: t < -1.41
#
# Conclusión:
# El estadístico t (-2.36) es menor que el valor crítico t (-1.41).
# Se rechaza la hipótesis nula (H0).
# Hay suficiente evidencia para concluir que el aumento promedio de hierro en la sangre es menor a 2 mg/dL.

# %% [markdown]
# EJERCICIO 28

# %%
import numpy as np
from scipy.stats import t

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 15 (El consumo promedio es de 15 km/L)
# Ha: μ < 15 (El consumo promedio es menor a 15 km/L)

# 2. Definir variables
mu_0 = 15  # Media poblacional hipotetizada
media_muestral = 14  # Media de la muestra
desviacion_estandar_muestral = 1.2  # Desviación estándar de la muestra
n = 10  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución t

# Requerimiento 2: Calcule el estadístico t.
error_estandar = desviacion_estandar_muestral / np.sqrt(n)
estadistico_t = (media_muestral - mu_0) / error_estandar

print(f"Estadístico t calculado: {estadistico_t:.2f}")

# Requerimiento 3: Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# Para una prueba de cola inferior con alpha = 0.05
valor_critico_t = t.ppf(alpha, grados_libertad)

print(f"Grados de libertad: {grados_libertad}")
print(f"Valor crítico t (alpha = {alpha}): {valor_critico_t:.2f}")
print(f"Región de rechazo: t < {valor_critico_t:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_t < valor_critico_t:
    print(f"El estadístico t ({estadistico_t:.2f}) es menor que el valor crítico t ({valor_critico_t:.2f}).")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el consumo promedio es menor a 15 km/L.")
else:
    print(f"El estadístico t ({estadistico_t:.2f}) no es menor que el valor crítico t ({valor_critico_t:.2f}).")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el consumo promedio es menor a 15 km/L.")
# Out:
# Estadístico t calculado: -2.64
# Grados de libertad: 9
# Valor crítico t (alpha = 0.05): -1.83
# Región de rechazo: t < -1.83
#
# Conclusión:
# El estadístico t (-2.64) es menor que el valor crítico t (-1.83).
# Se rechaza la hipótesis nula (H0).
# Hay suficiente evidencia para concluir que el consumo promedio es menor a 15 km/L.

# %% [markdown]
# EJERCICIO 27

# %%
import numpy as np
from scipy.stats import t

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 80 (El promedio de la clase en matemáticas es 80)
# Ha: μ ≠ 80 (El promedio de la clase en matemáticas es diferente de 80)

# 2. Definir variables
mu_0 = 80  # Media poblacional hipotetizada
media_muestral = 75  # Media de la muestra
desviacion_estandar_muestral = 8  # Desviación estándar de la muestra
n = 12  # Tamaño de la muestra
alpha = 0.01  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución t

# Requerimiento 2: Calcule el estadístico t.
error_estandar = desviacion_estandar_muestral / np.sqrt(n)
estadistico_t = (media_muestral - mu_0) / error_estandar

print(f"Estadístico t calculado: {estadistico_t:.2f}")

# Requerimiento 3: Determine los grados de libertad y los valores críticos, además de la región crítica y la región de rechazo.
# Para una prueba de dos colas con alpha = 0.01
alpha_div_2 = alpha / 2
valor_critico_t_inferior = t.ppf(alpha_div_2, grados_libertad)
valor_critico_t_superior = t.ppf(1 - alpha_div_2, grados_libertad)


print(f"Grados de libertad: {grados_libertad}")
print(f"Valores críticos t (alpha = {alpha}): {valor_critico_t_inferior:.2f} y {valor_critico_t_superior:.2f}")
print(f"Región de rechazo: t < {valor_critico_t_inferior:.2f} o t > {valor_critico_t_superior:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_t < valor_critico_t_inferior or estadistico_t > valor_critico_t_superior:
    print(f"El estadístico t ({estadistico_t:.2f}) cae en la región de rechazo.")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el promedio de la clase en matemáticas es diferente de 80.")
else:
    print(f"El estadístico t ({estadistico_t:.2f}) no cae en la región de rechazo.")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el promedio de la clase en matemáticas es diferente de 80.")
# Out:
# Estadístico t calculado: -2.17
# Grados de libertad: 11
# Valores críticos t (alpha = 0.01): -3.11 y 3.11
# Región de rechazo: t < -3.11 o t > 3.11
#
# Conclusión:
# El estadístico t (-2.17) no cae en la región de rechazo.
# No se rechaza la hipótesis nula (H0).
# No hay suficiente evidencia para concluir que el promedio de la clase en matemáticas es diferente de 80.

# %% [markdown]
# EJERCICIO 26

# %%
import numpy as np
from scipy.stats import t

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 25 (El tiempo promedio de entrega es de 25 minutos)
# Ha: μ > 25 (El tiempo promedio de entrega es mayor a 25 minutos)

# 2. Definir variables
mu_0 = 25  # Media poblacional hipotetizada
media_muestral = 28  # Media de la muestra
desviacion_estandar_muestral = 4  # Desviación estándar de la muestra
n = 15  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia
grados_libertad = n - 1 # grados de libertad para la distribución t

# Requerimiento 2: Calcule el estadístico t.
error_estandar = desviacion_estandar_muestral / np.sqrt(n)
estadistico_t = (media_muestral - mu_0) / error_estandar

print(f"Estadístico t calculado: {estadistico_t:.2f}")

# Requerimiento 3: Determine los grados de libertad y el valor crítico, además de la región crítica y la región de rechazo.
# Para una prueba de cola superior con alpha = 0.05
valor_critico_t = t.ppf(1 - alpha, grados_libertad)

print(f"Grados de libertad: {grados_libertad}")
print(f"Valor crítico t (alpha = {alpha}): {valor_critico_t:.2f}")
print(f"Región de rechazo: t > {valor_critico_t:.2f}")


# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_t > valor_critico_t:
    print(f"El estadístico t ({estadistico_t:.2f}) es mayor que el valor crítico t ({valor_critico_t:.2f}).")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el tiempo promedio de entrega a domicilio es mayor a 25 minutos.")
else:
    print(f"El estadístico t ({estadistico_t:.2f}) no es mayor que el valor crítico t ({valor_critico_t:.2f}).")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el tiempo promedio de entrega a domicilio es mayor a 25 minutos.")
# Out:
# Estadístico t calculado: 2.90
# Grados de libertad: 14
# Valor crítico t (alpha = 0.05): 1.76
# Región de rechazo: t > 1.76
#
# Conclusión:
# El estadístico t (2.90) es mayor que el valor crítico t (1.76).
# Se rechaza la hipótesis nula (H0).
# Hay suficiente evidencia para concluir que el tiempo promedio de entrega a domicilio es mayor a 25 minutos.

# %% [markdown]
# EJERCICIO 25

# %%
import numpy as np
from scipy.stats import norm

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 500 (El volumen promedio de llenado es de 500 mL)
# Ha: μ ≠ 500 (El volumen promedio de llenado es diferente de 500 mL)

# 2. Definir variables
mu_0 = 500  # Media poblacional hipotetizada
media_muestral = 498  # Media de la muestra
desviacion_estandar_poblacional = 5  # Desviación estándar poblacional
n = 60  # Tamaño de la muestra
alpha = 0.01  # Nivel de significancia

# Requerimiento 2: Calcule el estadístico Z.
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)
estadistico_z = (media_muestral - mu_0) / error_estandar

print(f"Estadístico Z calculado: {estadistico_z:.2f}")

# Requerimiento 3: Determine la región crítica y la región de rechazo.
# Para una prueba de dos colas con alpha = 0.01
alpha_div_2 = alpha / 2
valor_critico_z_inferior = norm.ppf(alpha_div_2)
valor_critico_z_superior = norm.ppf(1 - alpha_div_2)

print(f"Valores críticos Z (alpha = {alpha}): {valor_critico_z_inferior:.2f} y {valor_critico_z_superior:.2f}")
print(f"Región de rechazo: Z < {valor_critico_z_inferior:.2f} o Z > {valor_critico_z_superior:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_z < valor_critico_z_inferior or estadistico_z > valor_critico_z_superior:
    print(f"El estadístico Z ({estadistico_z:.2f}) cae en la región de rechazo.")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el volumen promedio de llenado es diferente de 500 mL.")
else:
    print(f"El estadístico Z ({estadistico_z:.2f}) no cae en la región de rechazo.")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el volumen promedio de llenado es diferente de 500 mL.")
# Out:
# Estadístico Z calculado: -3.10
# Valores críticos Z (alpha = 0.01): -2.58 y 2.58
# Región de rechazo: Z < -2.58 o Z > 2.58
#
# Conclusión:
# El estadístico Z (-3.10) cae en la región de rechazo.
# Se rechaza la hipótesis nula (H0).
# Hay suficiente evidencia para concluir que el volumen promedio de llenado es diferente de 500 mL.

# %% [markdown]
# EJERCICIO 24

# %%
import numpy as np
from scipy.stats import norm

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 10 (La reducción promedio de la presión arterial es de 10 mmHg)
# Ha: μ < 10 (La reducción promedio de la presión arterial es menor a 10 mmHg)

# 2. Definir variables
mu_0 = 10  # Media poblacional hipotetizada
media_muestral = 8  # Media de la muestra
desviacion_estandar_poblacional = 3  # Desviación estándar poblacional
n = 25  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia

# Requerimiento 2: Calcule el estadístico Z.
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)
estadistico_z = (media_muestral - mu_0) / error_estandar

print(f"Estadístico Z calculado: {estadistico_z:.2f}")

# Requerimiento 3: Determine la región crítica y la región de rechazo.
# Para una prueba de cola inferior con alpha = 0.05
valor_critico_z = norm.ppf(alpha)

print(f"Valor crítico Z (alpha = {alpha}): {valor_critico_z:.2f}")
print(f"Región de rechazo: Z < {valor_critico_z:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_z < valor_critico_z:
    print(f"El estadístico Z ({estadistico_z:.2f}) es menor que el valor crítico Z ({valor_critico_z:.2f}).")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el medicamento reduce la presión arterial en menos de 10 mmHg en promedio.")
else:
    print(f"El estadístico Z ({estadistico_z:.2f}) no es menor que el valor crítico Z ({valor_critico_z:.2f}).")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el medicamento reduce la presión arterial en menos de 10 mmHg en promedio.")
# Out:
# Estadístico Z calculado: -3.33
# Valor crítico Z (alpha = 0.05): -1.64
# Región de rechazo: Z < -1.64
#
# Conclusión:
# El estadístico Z (-3.33) es menor que el valor crítico Z (-1.64).
# Se rechaza la hipótesis nula (H0).
# Hay suficiente evidencia para concluir que el medicamento reduce la presión arterial en menos de 10 mmHg en promedio.

# %% [markdown]
# EJERCICIO 23

# %%
import numpy as np
from scipy.stats import norm

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 75 (El promedio de la clase es igual al promedio nacional)
# Ha: μ ≠ 75 (El promedio de la clase es diferente al promedio nacional)

# 2. Definir variables
mu_0 = 75  # Media poblacional hipotetizada
media_muestral = 78  # Media de la muestra
desviacion_estandar_poblacional = 12  # Desviación estándar poblacional
n = 36  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia

# Requerimiento 2: Calcule el estadístico Z.
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)
estadistico_z = (media_muestral - mu_0) / error_estandar

print(f"Estadístico Z calculado: {estadistico_z:.2f}")

# Requerimiento 3: Determine la región crítica y la región de rechazo.
# Para una prueba de dos colas con alpha = 0.05
alpha_div_2 = alpha / 2
valor_critico_z_inferior = norm.ppf(alpha_div_2)
valor_critico_z_superior = norm.ppf(1 - alpha_div_2)

print(f"Valores críticos Z (alpha = {alpha}): {valor_critico_z_inferior:.2f} y {valor_critico_z_superior:.2f}")
print(f"Región de rechazo: Z < {valor_critico_z_inferior:.2f} o Z > {valor_critico_z_superior:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_z < valor_critico_z_inferior or estadistico_z > valor_critico_z_superior:
    print(f"El estadístico Z ({estadistico_z:.2f}) cae en la región de rechazo.")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el promedio de la clase es diferente al promedio nacional de 75 puntos.")
else:
    print(f"El estadístico Z ({estadistico_z:.2f}) no cae en la región de rechazo.")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el promedio de la clase es diferente al promedio nacional de 75 puntos.")
# Out:
# Estadístico Z calculado: 1.50
# Valores críticos Z (alpha = 0.05): -1.96 y 1.96
# Región de rechazo: Z < -1.96 o Z > 1.96
#
# Conclusión:
# El estadístico Z (1.50) no cae en la región de rechazo.
# No se rechaza la hipótesis nula (H0).
# No hay suficiente evidencia para concluir que el promedio de la clase es diferente al promedio nacional de 75 puntos.

# %% [markdown]
# EJERCICIO 22

# %%
import numpy as np
from scipy.stats import norm

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 1200 (La duración promedio de las baterías es de 1200 horas)
# Ha: μ < 1200 (La duración promedio de las baterías es menor a 1200 horas)

# 2. Definir variables
mu_0 = 1200  # Media poblacional hipotetizada
media_muestral = 1180  # Media de la muestra
desviacion_estandar_poblacional = 100  # Desviación estándar poblacional
n = 50  # Tamaño de la muestra
alpha = 0.01  # Nivel de significancia

# Requerimiento 2: Calcule el estadístico Z.
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)
estadistico_z = (media_muestral - mu_0) / error_estandar

print(f"Estadístico Z calculado: {estadistico_z:.2f}")

# Requerimiento 3: Determine la región crítica y la región de rechazo.
# Para una prueba de cola inferior con alpha = 0.01
valor_critico_z = norm.ppf(alpha)

print(f"Valor crítico Z (alpha = {alpha}): {valor_critico_z:.2f}")
print(f"Región de rechazo: Z < {valor_critico_z:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_z < valor_critico_z:
    print(f"El estadístico Z ({estadistico_z:.2f}) es menor que el valor crítico Z ({valor_critico_z:.2f}).")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que la duración promedio de las baterías es menor a 1200 horas.")
else:
    print(f"El estadístico Z ({estadistico_z:.2f}) no es menor que el valor crítico Z ({valor_critico_z:.2f}).")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que la duración promedio de las baterías es menor a 1200 horas.")
# Out:
# Estadístico Z calculado: -1.41
# Valor crítico Z (alpha = 0.01): -2.33
# Región de rechazo: Z < -2.33
#
# Conclusión:
# El estadístico Z (-1.41) no es menor que el valor crítico Z (-2.33).
# No se rechaza la hipótesis nula (H0).
# No hay suficiente evidencia para concluir que la duración promedio de las baterías es menor a 1200 horas.

# %% [markdown]
# EJERCICIO 21

# %%
import numpy as np
from scipy.stats import norm

# Requerimiento 1: Plantear las hipótesis nula y alternativa.
# H0: μ = 500 (El peso promedio de los paquetes es de 500 g)
# Ha: μ < 500 (El peso promedio de los paquetes es menor a 500 g - subllenando)

# 2. Definir variables
mu_0 = 500  # Media poblacional hipotetizada
media_muestral = 495  # Media de la muestra
desviacion_estandar_poblacional = 15  # Desviación estándar poblacional
n = 40  # Tamaño de la muestra
alpha = 0.05  # Nivel de significancia

# Requerimiento 2: Calcule el estadístico Z.
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)
estadistico_z = (media_muestral - mu_0) / error_estandar

print(f"Estadístico Z calculado: {estadistico_z:.2f}")

# Requerimiento 3: Determine la región crítica y la región de rechazo.
# Para una prueba de cola inferior con alpha = 0.05
valor_critico_z = norm.ppf(alpha)

print(f"Valor crítico Z (alpha = {alpha}): {valor_critico_z:.2f}")
print(f"Región de rechazo: Z < {valor_critico_z:.2f}")

# Requerimiento 4: Concluya si se rechaza H0.
print("\nConclusión:")
if estadistico_z < valor_critico_z:
    print(f"El estadístico Z ({estadistico_z:.2f}) es menor que el valor crítico Z ({valor_critico_z:.2f}).")
    print("Se rechaza la hipótesis nula (H0).")
    print("Hay suficiente evidencia para concluir que el peso promedio de los paquetes es menor a 500 g.")
else:
    print(f"El estadístico Z ({estadistico_z:.2f}) no es menor que el valor crítico Z ({valor_critico_z:.2f}).")
    print("No se rechaza la hipótesis nula (H0).")
    print("No hay suficiente evidencia para concluir que el peso promedio de los paquetes es menor a 500 g.")
# Out:
# Estadístico Z calculado: -2.11
# Valor crítico Z (alpha = 0.05): -1.64
# Región de rechazo: Z < -1.64
#
# Conclusión:
# El estadístico Z (-2.11) es menor que el valor crítico Z (-1.64).
# Se rechaza la hipótesis nula (H0).
# Hay suficiente evidencia para concluir que el peso promedio de los paquetes es menor a 500 g.

# %% [markdown]
# EJERCICIO 20

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
desviacion_estandar_poblacional = 12  # desviación estándar poblacional
margen_error = 3  # margen de error deseado
nivel_confianza = 0.90  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el tamaño de muestra necesario
n_necesario = (valor_z**2 * desviacion_estandar_poblacional**2) / (margen_error**2)

print(f"Tamaño de muestra necesario: {np.ceil(n_necesario):.0f}")
# Out:
# Tamaño de muestra necesario: 44

# %% [markdown]
# EJERCICIO 19

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
desviacion_estandar_poblacional = 5  # desviación estándar poblacional
margen_error = 1.5  # margen de error deseado
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el tamaño de muestra necesario
n_necesario = (valor_z**2 * desviacion_estandar_poblacional**2) / (margen_error**2)

print(f"Tamaño de muestra necesario: {np.ceil(n_necesario):.0f}")
# Out:
# Tamaño de muestra necesario: 43

# %% [markdown]
# EJERCICIO 18

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
desviacion_estandar_poblacional = 1.2  # desviación estándar poblacional
margen_error = 0.5  # margen de error deseado
nivel_confianza = 0.99  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el tamaño de muestra necesario
n_necesario = (valor_z**2 * desviacion_estandar_poblacional**2) / (margen_error**2)

print(f"Tamaño de muestra necesario: {np.ceil(n_necesario):.0f}")
# Out:
# Tamaño de muestra necesario: 39

# %% [markdown]
# EJERCICIO 17

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
desviacion_estandar_poblacional = 50  # desviación estándar poblacional
margen_error = 10  # margen de error deseado
nivel_confianza = 0.90  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el tamaño de muestra necesario
n_necesario = (valor_z**2 * desviacion_estandar_poblacional**2) / (margen_error**2)

print(f"Tamaño de muestra necesario: {np.ceil(n_necesario):.0f}")
# Out:
# Tamaño de muestra necesario: 68

# %% [markdown]
# EJERCICIO 16

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
desviacion_estandar_poblacional = 8  # desviación estándar poblacional
margen_error = 2  # margen de error deseado
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el tamaño de muestra necesario
n_necesario = (valor_z**2 * desviacion_estandar_poblacional**2) / (margen_error**2)

print(f"Tamaño de muestra necesario: {np.ceil(n_necesario):.0f}")
# Out:
# Tamaño de muestra necesario: 62

# %% [markdown]
# EJERCICIO 15

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
margen_error = 0.04  # margen de error deseado
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# Caso 1: Con prueba preliminar
p_estimado = 0.69  # proporción estimada de la prueba preliminar
q_estimado = 1 - p_estimado
n_con_prueba = (valor_z**2 * p_estimado * q_estimado) / (margen_error**2)

print(f"Tamaño de muestra necesario con prueba preliminar (p = {p_estimado}): {np.ceil(n_con_prueba):.0f}")

# Caso 2: Conservador (usando p = 0.5 para maximizar el tamaño de muestra)
p_conservador = 0.5
q_conservador = 1 - p_conservador
n_conservador = (valor_z**2 * p_conservador * q_conservador) / (margen_error**2)

print(f"Tamaño de muestra necesario conservador (p = {p_conservador}): {np.ceil(n_conservador):.0f}")
# Out:
# Tamaño de muestra necesario con prueba preliminar (p = 0.69): 514
# Tamaño de muestra necesario conservador (p = 0.5): 601

# %% [markdown]
# EJERCICIO 14

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
margen_error = 0.05  # margen de error deseado
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# Caso 1: Con encuesta informal
p_estimado = 0.56  # proporción estimada de la encuesta informal
q_estimado = 1 - p_estimado
n_con_encuesta = (valor_z**2 * p_estimado * q_estimado) / (margen_error**2)

print(f"Tamaño de muestra necesario con encuesta informal (p = {p_estimado}): {np.ceil(n_con_encuesta):.0f}")

# Caso 2: Sin datos preliminares (usando p = 0.5 para maximizar el tamaño de muestra)
p_sin_datos = 0.5
q_sin_datos = 1 - p_sin_datos
n_sin_datos = (valor_z**2 * p_sin_datos * q_sin_datos) / (margen_error**2)

print(f"Tamaño de muestra necesario sin datos preliminares (p = {p_sin_datos}): {np.ceil(n_sin_datos):.0f}")
# Out:
# Tamaño de muestra necesario con encuesta informal (p = 0.56): 379
# Tamaño de muestra necesario sin datos preliminares (p = 0.5): 385

# %% [markdown]
# EJERCICIO 13

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
margen_error = 0.02  # margen de error deseado
nivel_confianza = 0.99  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# Caso 1: Con encuesta previa
p_estimado = 0.42  # proporción estimada de la encuesta previa
q_estimado = 1 - p_estimado
n_con_encuesta = (valor_z**2 * p_estimado * q_estimado) / (margen_error**2)

print(f"Tamaño de muestra necesario con encuesta previa (p = {p_estimado}): {np.ceil(n_con_encuesta):.0f}")

# Caso 2: Sin encuesta previa (usando p = 0.5 para maximizar el tamaño de muestra)
p_sin_encuesta = 0.5
q_sin_encuesta = 1 - p_sin_encuesta
n_sin_encuesta = (valor_z**2 * p_sin_encuesta * q_sin_encuesta) / (margen_error**2)

print(f"Tamaño de muestra necesario sin encuesta previa (p = {p_sin_encuesta}): {np.ceil(n_sin_encuesta):.0f}")
# Out:
# Tamaño de muestra necesario con encuesta previa (p = 0.42): 4041
# Tamaño de muestra necesario sin encuesta previa (p = 0.5): 4147

# %% [markdown]
# EJERCICIO 12

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
margen_error = 0.04  # margen de error deseado
nivel_confianza = 0.90  # nivel de confianza
p_estimado = 0.07  # proporción estimada de datos históricos
q_estimado = 1 - p_estimado

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el tamaño de muestra necesario
n_necesario = (valor_z**2 * p_estimado * q_estimado) / (margen_error**2)

print(f"Tamaño de muestra necesario (p = {p_estimado}): {np.ceil(n_necesario):.0f}")
# Out:
# Tamaño de muestra necesario (p = 0.07): 111

# %% [markdown]
# EJERCICIO 11

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
margen_error = 0.03  # margen de error deseado
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z para el nivel de confianza
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# Caso 1: Con estudio piloto
p_estimado = 0.72  # proporción estimada del estudio piloto
q_estimado = 1 - p_estimado
n_con_piloto = (valor_z**2 * p_estimado * q_estimado) / (margen_error**2)

print(f"Tamaño de muestra necesario con estudio piloto (p = {p_estimado}): {np.ceil(n_con_piloto):.0f}")

# Caso 2: Sin estudio piloto (usando p = 0.5 para maximizar el tamaño de muestra)
p_sin_piloto = 0.5
q_sin_piloto = 1 - p_sin_piloto
n_sin_piloto = (valor_z**2 * p_sin_piloto * q_sin_piloto) / (margen_error**2)

print(f"Tamaño de muestra necesario sin estudio piloto (p = {p_sin_piloto}): {np.ceil(n_sin_piloto):.0f}")
# Out:
# Tamaño de muestra necesario con estudio piloto (p = 0.72): 861
# Tamaño de muestra necesario sin estudio piloto (p = 0.5): 1068

# %% [markdown]
# EJERCICIO 10

# %%
import numpy as np
from scipy.stats import t

# 1. Definir variables
n = 8  # tamaño de la muestra
media_muestral = 1.5  # media de la muestra
desviacion_estandar_muestral = 0.3  # desviación estándar de la muestra
nivel_confianza = 0.95  # nivel de confianza
grados_libertad = n - 1 # grados de libertad para la distribución t

# 2. Calcular el valor t
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_t = t.ppf(1 - alpha_div_2, grados_libertad)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_muestral / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_t * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 95.0% para la media poblacional es:
# [1.25, 1.75]

# %% [markdown]
# EJERCICIO 9

# %%
import numpy as np
from scipy.stats import t

# 1. Definir variables
n = 20  # tamaño de la muestra
media_muestral = 30  # media de la muestra
desviacion_estandar_muestral = 4  # desviación estándar de la muestra
nivel_confianza = 0.95  # nivel de confianza
grados_libertad = n - 1 # grados de libertad para la distribución t

# 2. Calcular el valor t
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_t = t.ppf(1 - alpha_div_2, grados_libertad)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_muestral / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_t * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 95.0% para la media poblacional es:
# [28.13, 31.87]

# %% [markdown]
# EJERCICIO 8

# %%
import numpy as np
from scipy.stats import t

# 1. Definir variables
n = 10  # tamaño de la muestra
media_muestral = 25  # media de la muestra
desviacion_estandar_muestral = 3  # desviación estándar de la muestra
nivel_confianza = 0.99  # nivel de confianza
grados_libertad = n - 1 # grados de libertad para la distribución t

# 2. Calcular el valor t
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_t = t.ppf(1 - alpha_div_2, grados_libertad)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_muestral / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_t * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 99.0% para la media poblacional es:
# [21.92, 28.08]

# %% [markdown]
# EJERCICIO 7

# %%
import numpy as np
from scipy.stats import t

# 1. Definir variables
n = 15  # tamaño de la muestra
media_muestral = 8  # media de la muestra
desviacion_estandar_muestral = 1.2  # desviación estándar de la muestra
nivel_confianza = 0.90  # nivel de confianza
grados_libertad = n - 1 # grados de libertad para la distribución t

# 2. Calcular el valor t
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_t = t.ppf(1 - alpha_div_2, grados_libertad)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_muestral / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_t * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 90.0% para la media poblacional es:
# [7.45, 8.55]

# %% [markdown]
# EJERCICIO 6

# %%
import numpy as np
from scipy.stats import t

# 1. Definir variables
n = 12  # tamaño de la muestra
media_muestral = 84  # media de la muestra
desviacion_estandar_muestral = 5  # desviación estándar de la muestra
nivel_confianza = 0.95  # nivel de confianza
grados_libertad = n - 1 # grados de libertad para la distribución t

# 2. Calcular el valor t
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_t = t.ppf(1 - alpha_div_2, grados_libertad)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_muestral / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_t * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 95.0% para la media poblacional es:
# [80.82, 87.18]

# %% [markdown]
# EJERCICIO 5

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
n = 40  # tamaño de la muestra
media_muestral = 20  # media de la muestra
desviacion_estandar_poblacional = 4  # desviación estándar poblacional
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_z * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 95.0% para la media poblacional es:
# [18.76, 21.24]

# %% [markdown]
# EJERCICIO 4

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
n = 25  # tamaño de la muestra
media_muestral = 12  # media de la muestra
desviacion_estandar_poblacional = 1.5  # desviación estándar poblacional
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_z * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 95.0% para la media poblacional es:
# [11.41, 12.59]

# %% [markdown]
# EJERCICIO 3

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
n = 30  # tamaño de la muestra
media_muestral = 2.5  # media de la muestra
desviacion_estandar_poblacional = 0.2  # desviación estándar poblacional
nivel_confianza = 0.99  # nivel de confianza

# 2. Calcular el valor Z
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_z * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 99.0% para la media poblacional es:
# [2.41, 2.59]

# %% [markdown]
# EJERCICIO 2

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
n = 100  # tamaño de la muestra
media_muestral = 75  # media de la muestra
desviacion_estandar_poblacional = 15  # desviación estándar poblacional
nivel_confianza = 0.90  # nivel de confianza

# 2. Calcular el valor Z
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_z * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 90.0% para la media poblacional es:
# [72.53, 77.47]

# %% [markdown]
# EJERCICIO 1

# %%
import numpy as np
from scipy.stats import norm

# 1. Definir variables
n = 50  # tamaño de la muestra
media_muestral = 170  # media de la muestra
desviacion_estandar_poblacional = 10  # desviación estándar poblacional
nivel_confianza = 0.95  # nivel de confianza

# 2. Calcular el valor Z
alpha = 1 - nivel_confianza
alpha_div_2 = alpha / 2
valor_z = norm.ppf(1 - alpha_div_2)

# 3. Calcular el error estándar
error_estandar = desviacion_estandar_poblacional / np.sqrt(n)

# 4. Calcular el margen de error
margen_error = valor_z * error_estandar

# 5. Construir el intervalo de confianza
limite_inferior = media_muestral - margen_error
limite_superior = media_muestral + margen_error

# 6. Mostrar resultados
print(f"El intervalo de confianza del {nivel_confianza*100}% para la media poblacional es:")
print(f"[{limite_inferior:.2f}, {limite_superior:.2f}]")
# Out:
# El intervalo de confianza del 95.0% para la media poblacional es:
# [167.23, 172.77]
